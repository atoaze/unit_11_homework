# %% [markdown]
# # Fitting and Testing a Neural Network
#
# **Note:** The first three sections of this notebook are the same steps followed on the previous demos.

# %%
# Initial imports
import pandas as pd
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# Keras modules
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
# Out:
# 2023-11-13 18:38:40.371829: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Data Generation and Preprocessing

# %%
# Generate 1000 demo data samples with 2 features and two centers
X, y = make_blobs(n_samples=1000, centers=2, n_features=2, random_state=1)

# %%
# Transforming y to a vertical vector
y = y.reshape(-1, 1)
y.shape
# Out:
# (1000, 1)

# %%
# Creating a DataFrame with the dummy data
df = pd.DataFrame(X, columns=["Feature 1", "Feature 2"])
df["Target"] = y
df.head()
# Out:
#    Feature 1  Feature 2  Target
# 0  -3.058373   4.488258       0
# 1  -8.609739  -3.727149       1
# 2   1.371297   5.231074       0
# 3  -9.339176  -2.954447       1
# 4 -11.571786  -3.852755       1

# %%
# Plotting the dummy data
df.plot.scatter(x="Feature 1", y="Feature 2", c="Target", colormap="winter")
# Out:
# <Axes: xlabel='Feature 1', ylabel='Feature 2'>

# %%
# Create training and testing datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create scaler instance
X_scaler = StandardScaler()

# Fit the scaler
X_scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Creating a Neural Network Model

# %%
# Create a sequential neural network model
neuron = Sequential()

# %%
# Add the input and the hidden layer to the model
number_inputs = 2
number_hidden_nodes = 3

neuron.add(Dense(units=number_hidden_nodes, activation="relu", input_dim=number_inputs))

# %%
# Add the output layer
number_classes = 1

neuron.add(Dense(units=number_classes, activation="sigmoid"))

# %%
# Display model summary
neuron.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 3)                 9
#
#  dense_1 (Dense)             (None, 1)                 4
#
# =================================================================
# Total params: 13 (52.00 Byte)
# Trainable params: 13 (52.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Compiling a Neural Network Model

# %%
neuron.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %% [markdown]
# ## Fitting and Testing a Neural Network

# %%
# Fitting the model
model = neuron.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 1s 2ms/step - loss: 1.3350 - accuracy: 0.0000e+00
# Epoch 2/100
# 24/24 [==============================] - 0s 2ms/step - loss: 1.2546 - accuracy: 0.0000e+00
# Epoch 3/100
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1820 - accuracy: 0.0000e+00
# Epoch 4/100
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1187 - accuracy: 0.0000e+00
# Epoch 5/100
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0638 - accuracy: 0.0000e+00
# Epoch 6/100
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0154 - accuracy: 0.0000e+00
# Epoch 7/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9717 - accuracy: 0.0000e+00
# Epoch 8/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9340 - accuracy: 0.0000e+00
# Epoch 9/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9002 - accuracy: 0.0000e+00
# Epoch 10/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8702 - accuracy: 0.0013
# Epoch 11/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8438 - accuracy: 0.0053
# Epoch 12/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8192 - accuracy: 0.0120
# Epoch 13/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7975 - accuracy: 0.0173
# Epoch 14/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7788 - accuracy: 0.0333
# Epoch 15/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7633 - accuracy: 0.0720
# Epoch 16/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7519 - accuracy: 0.1107
# Epoch 17/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7435 - accuracy: 0.1680
# Epoch 18/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7370 - accuracy: 0.2480
# Epoch 19/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7313 - accuracy: 0.3040
# Epoch 20/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7265 - accuracy: 0.3627
# Epoch 21/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7221 - accuracy: 0.4093
# Epoch 22/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7179 - accuracy: 0.4547
# Epoch 23/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7141 - accuracy: 0.4773
# Epoch 24/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7105 - accuracy: 0.4867
# Epoch 25/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7071 - accuracy: 0.4987
# Epoch 26/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7043 - accuracy: 0.5013
# Epoch 27/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7017 - accuracy: 0.5027
# Epoch 28/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6997 - accuracy: 0.5027
# Epoch 29/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6981 - accuracy: 0.5067
# Epoch 30/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6969 - accuracy: 0.5067
# Epoch 31/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6961 - accuracy: 0.5067
# Epoch 32/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6953 - accuracy: 0.5067
# Epoch 33/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6948 - accuracy: 0.5067
# Epoch 34/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6944 - accuracy: 0.5067
# Epoch 35/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6940 - accuracy: 0.5067
# Epoch 36/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6936 - accuracy: 0.5067
# Epoch 37/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6930 - accuracy: 0.5067
# Epoch 38/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6919 - accuracy: 0.5067
# Epoch 39/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6897 - accuracy: 0.5067
# Epoch 40/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6849 - accuracy: 0.5107
# Epoch 41/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6754 - accuracy: 0.6773
# Epoch 42/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6589 - accuracy: 0.9547
# Epoch 43/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6353 - accuracy: 0.9960
# Epoch 44/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6062 - accuracy: 0.9987
# Epoch 45/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5736 - accuracy: 0.9987
# Epoch 46/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5413 - accuracy: 0.9987
# Epoch 47/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5099 - accuracy: 0.9987
# Epoch 48/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4810 - accuracy: 1.0000
# Epoch 49/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4545 - accuracy: 1.0000
# Epoch 50/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4308 - accuracy: 1.0000
# Epoch 51/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4094 - accuracy: 1.0000
# Epoch 52/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3902 - accuracy: 1.0000
# Epoch 53/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3728 - accuracy: 1.0000
# Epoch 54/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3572 - accuracy: 1.0000
# Epoch 55/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3428 - accuracy: 1.0000
# Epoch 56/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3297 - accuracy: 1.0000
# Epoch 57/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3177 - accuracy: 1.0000
# Epoch 58/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3065 - accuracy: 1.0000
# Epoch 59/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2962 - accuracy: 1.0000
# Epoch 60/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2864 - accuracy: 1.0000
# Epoch 61/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2774 - accuracy: 1.0000
# Epoch 62/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2689 - accuracy: 1.0000
# Epoch 63/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2609 - accuracy: 1.0000
# Epoch 64/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2534 - accuracy: 1.0000
# Epoch 65/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2463 - accuracy: 1.0000
# Epoch 66/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2396 - accuracy: 1.0000
# Epoch 67/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2332 - accuracy: 1.0000
# Epoch 68/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2271 - accuracy: 1.0000
# Epoch 69/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2213 - accuracy: 1.0000
# Epoch 70/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2157 - accuracy: 1.0000
# Epoch 71/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2104 - accuracy: 1.0000
# Epoch 72/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2054 - accuracy: 1.0000
# Epoch 73/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2005 - accuracy: 1.0000
# Epoch 74/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1959 - accuracy: 1.0000
# Epoch 75/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1914 - accuracy: 1.0000
# Epoch 76/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1871 - accuracy: 1.0000
# Epoch 77/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1830 - accuracy: 1.0000
# Epoch 78/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1790 - accuracy: 1.0000
# Epoch 79/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1752 - accuracy: 1.0000
# Epoch 80/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1715 - accuracy: 1.0000
# Epoch 81/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1679 - accuracy: 1.0000
# Epoch 82/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1645 - accuracy: 1.0000
# Epoch 83/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1611 - accuracy: 1.0000
# Epoch 84/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1579 - accuracy: 1.0000
# Epoch 85/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1547 - accuracy: 1.0000
# Epoch 86/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1517 - accuracy: 1.0000
# Epoch 87/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1487 - accuracy: 1.0000
# Epoch 88/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1459 - accuracy: 1.0000
# Epoch 89/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1431 - accuracy: 1.0000
# Epoch 90/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1404 - accuracy: 1.0000
# Epoch 91/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1378 - accuracy: 1.0000
# Epoch 92/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1353 - accuracy: 1.0000
# Epoch 93/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1328 - accuracy: 1.0000
# Epoch 94/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1304 - accuracy: 1.0000
# Epoch 95/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1281 - accuracy: 1.0000
# Epoch 96/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1258 - accuracy: 1.0000
# Epoch 97/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1236 - accuracy: 1.0000
# Epoch 98/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1214 - accuracy: 1.0000
# Epoch 99/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1193 - accuracy: 1.0000
# Epoch 100/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1172 - accuracy: 1.0000

# %% [markdown]
# ## Plotting Loss and Accuracy

# %%
# Create a DataFrame with the history dictionary
df = pd.DataFrame(model.history, index=range(1, len(model.history["loss"]) + 1))

# %%
# Plot the loss
df.plot(y="loss")
# Out:
# <Axes: >

# %%
# Plot the accuracy
df.plot(y="accuracy")
# Out:
# <Axes: >

# %% [markdown]
# ### Evaluating the Model Performance

# %%
# Evaluate the model using testing data
model_loss, model_accuracy = neuron.evaluate(X_test_scaled, y_test, verbose=2)

# Display evaluation results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8/8 - 0s - loss: 0.1098 - accuracy: 1.0000 - 175ms/epoch - 22ms/step
# Loss: 0.10977699607610703, Accuracy: 1.0
